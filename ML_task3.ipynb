# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from skimage.io import imread
from skimage.transform import resize
import os

# %%
datadir='train3/'
images = []
labels = []
for i in os.listdir(datadir):
    img_path = os.path.join(datadir,i)
    img = imread(img_path)
    img_resized = resize(img, (64,64))
    images.append(img_resized.flatten())  # Flatten the image
    # labels.append(label)
    if 'cat' in i:
        labels.append(0)
    if 'dog' in i:
        labels.append(1)

labels = np.array(labels)
images = np.array(images)

# %%
print(images)
# Out:
# [[0.81046104 0.6575167  0.35555513 ... 0.00857414 0.0087858  0.00091144]
#  [0.15303416 0.17015273 0.16498222 ... 0.17959339 0.13056525 0.10397594]
#  [0.13208536 0.1565743  0.18784104 ... 0.7146657  0.6997991  0.03091452]
#  ...
#  [0.39054698 0.36614849 0.36990648 ... 0.70269385 0.65767618 0.65821151]
#  [0.70758253 0.52534049 0.39177951 ... 0.58921256 0.41136542 0.31929561]
#  [0.69803922 0.69803922 0.69803922 ... 0.631457   0.40400602 0.07459426]]

# %%
df=pd.DataFrame(images)
df['labels']=labels
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.810461  0.657517  0.355555  0.835218  0.680625  0.378251  0.867515
# 1  0.153034  0.170153  0.164982  0.169443  0.182440  0.202955  0.166240
# 2  0.132085  0.156574  0.187841  0.155844  0.178066  0.224885  0.172808
# 3  0.869714  0.873635  0.854028  0.874746  0.878602  0.859267  0.893177
# 4  0.278082  0.991807  0.995726  0.278388  0.992114  0.996021  0.283545
#
#           7         8         9  ...     12279     12280     12281     12282  \
# 0  0.701230  0.395934  0.888483  ...  0.008779  0.009194  0.000911  0.008772
# 1  0.181175  0.188083  0.140840  ...  0.307866  0.237933  0.222727  0.265270
# 2  0.196264  0.238614  0.190877  ...  0.693014  0.662776  0.055816  0.744480
# 3  0.894221  0.889057  0.902053  ...  0.849043  0.858320  0.858257  0.847114
# 4  0.996895  0.999205  0.291805  ...  0.615676  0.915650  0.889626  0.540798
#
#       12283     12284     12285     12286     12287  labels
# ...

# %%
y=df.labels
x=df.drop("labels",axis=1)

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 245    1
# 246    1
# 247    1
# 248    1
# 249    1
# Name: labels, Length: 250, dtype: int32

# %%
x
# Out:
#         0         1         2         3         4         5         6      \
# 0    0.810461  0.657517  0.355555  0.835218  0.680625  0.378251  0.867515
# 1    0.153034  0.170153  0.164982  0.169443  0.182440  0.202955  0.166240
# 2    0.132085  0.156574  0.187841  0.155844  0.178066  0.224885  0.172808
# 3    0.869714  0.873635  0.854028  0.874746  0.878602  0.859267  0.893177
# 4    0.278082  0.991807  0.995726  0.278388  0.992114  0.996021  0.283545
# ..        ...       ...       ...       ...       ...       ...       ...
# 245  0.024481  0.051427  0.064722  0.010632  0.019441  0.038318  0.011678
# 246  0.426148  0.305052  0.090180  0.465418  0.347636  0.098614  0.510658
# 247  0.390547  0.366148  0.369906  0.392762  0.382448  0.399013  0.418161
# 248  0.707583  0.525340  0.391780  0.710645  0.530510  0.393530  0.722635
# 249  0.698039  0.698039  0.698039  0.698039  0.698039  0.698039  0.698039
#
#         7         8         9      ...     12278     12279     12280  \
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
svm = SVC(kernel='linear')  # You can experiment with other kernels like 'rbf'
svm.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = svm.predict(x_test)
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
# Out:
# Accuracy: 0.58

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'C': [10, 20, 50],
    'kernel': ['poly', 'rbf']
}
GCV = GridSearchCV(SVC(kernel="poly"),param_grid,return_train_score=False)
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=SVC(kernel='poly'),
#              param_grid={'C': [10, 20, 50], 'kernel': ['poly', 'rbf']})

# %%
GCV.best_params_
# Out:
# {'C': 10, 'kernel': 'poly'}

# %%
GCV.best_score_
# Out:
# 0.585

# %%
best_estimator=GCV.best_estimator_
y_pred = best_estimator.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.6
